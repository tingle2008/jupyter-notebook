# %%
  library(lattice)
  print(xyplot(1:10 ~ 1:11))
# Out:
# plot without title

# %%
a <- 'hahah'

# %%
ls()
# Out:
# [1] "a"

# %%
getcwd()
# Out:
# Error in eval(expr, envir, enclos): could not find function "getcwd"
# Traceback:

# %%
getpwd()
# Out:
# Error in eval(expr, envir, enclos): could not find function "getpwd"
# Traceback:

# %% [markdown]
# ![Image of Yaktocat](https://octodex.github.com/images/yaktocat.png)
